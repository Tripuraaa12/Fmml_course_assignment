# %% [markdown]
# <a href="https://colab.research.google.com/github/Tripuraaa12/Fmml_course_assignment/blob/main/Module_04_Project_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **FOUNDATIONS OF MODERN MACHINE LEARNING, IIIT Hyderabad**
# ### Project for Module: Perceptron and Gradient Descent
#
# NOTE: YOU NEED TO WRITE CODE IN CELLS THAT SPECIFICALLY MENTION TASK-1, TASK-2, etc.
#
# WRITE ANY OBSERVATION(S), IF REQUIRED BY THE TASK, IN A SEPARATE CELL AT THE BOTTOM OF THE NOTEBOOK.
#
# ---

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
##########################
##########################

## TASK-1 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient =df(new_x)
    new_x = previous_x - step_multiplier * gradient

    step_size = abs(new_x - previous_x)
    # print(step_size)

    x_list.append(new_x)
    slope_list.append## [REQUIRED])

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 50
# Local minimum occurs at: -0.49996003706460423
# Slope or df(x) value at this point is: 7.992587079153068e-05
# f(x) value or cost at this point is: 0.7500000015970362

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function and its derivative
def f(x):
    return x**2 + x + 1

def df(x):
    return 2*x + 1

# Gradient Descent function
def gradient_descent(starting_point, learning_rate, iterations):
    x_values = [starting_point]
    for _ in range(iterations):
        current_x = x_values[-1]
        new_x = current_x - learning_rate * df(current_x)
        x_values.append(new_x)
    return x_values

# Data
x_1 = np.linspace(-3, 3, 1000)
x_list = gradient_descent(starting_point=2, learning_rate=0.8, iterations=10)
f_values = f(np.array(x_list))
slope_list = df(np.array(x_list))

# Superimpose the gradient descent calculations on the plot
plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)
plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)
plt.scatter(x_list, f_values, color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)
plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.6)
# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)
plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)

# Superimpose gradient descent path
for i in range(1, len(x_list)):
    plt.arrow(x_list[i-1], f_values[i-1], x_list[i] - x_list[i-1], f_values[i] - f_values[i-1],
              shape='full', lw=0, length_includes_head=True, head_width=0.2)

plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
##########################
##########################

## TASK-2 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return  ## [REQUIRED]

def dg(x):
    return ## [REQUIRED]

# %%
## TASK-3 : Plot function and derivative side by side like has been done earlier

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
def gradient_descent(dg, param1, param2, param3):
    # Implement gradient descent logic here
    # Calculate local_min, list_x, and deriv_list
    # Make sure to return these values
    # Example placeholder values for demonstration purposes:
    local_min = 0
    list_x = [0, 0.1, 0.2, 0.3]
    deriv_list = [0.1, 0.15, 0.08, 0.03]
    return local_min, list_x, deriv_list

# Using the gradient_descent function
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)

# Displaying results
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 0
# Number of steps: 4

# %%
def gradient_descent(derivative_func, initial_guess, multiplier, precision):
    # Implement gradient descent logic here
    # Calculate local_min, list_x, and deriv_list
    # Make sure to return these values
    # Example placeholder values for demonstration purposes:
    local_min = 0
    list_x = [0, 0.1, 0.2, 0.3]
    deriv_list = [0.1, 0.15, 0.08, 0.03]
    return local_min, list_x, deriv_list

# Calling gradient_descent with named arguments
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=-0.5, multiplier=0.01, precision=0.0001)

# Displaying results
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 0
# Number of steps: 4

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.01, precision=0.001):
    # Implement gradient descent logic here
    # Calculate local_min, list_x, and deriv_list
    # Make sure to return these values
    # Example placeholder values for demonstration purposes:
    local_min = 0
    list_x = [0, 0.1, 0.2, 0.3]
    deriv_list = [0.1, 0.15, 0.08, 0.03]
    return local_min, list_x, deriv_list

# Calling gradient_descent with specific named argument and default values for others
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=-0.1)

# Displaying results
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 0
# Number of steps: 4

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming these functions are defined somewhere in your code
def g(x):
    return x**2  # Replace with your actual cost function

def dg(x):
    return 2*x   # Replace with the derivative of your cost function

def gradient_descent(derivative_func, initial_guess, multiplier=0.01, precision=0.001):
    # Implement gradient descent logic here
    # Calculate local_min, list_x, and deriv_list
    # Example placeholder values for demonstration purposes:
    local_min = 0
    list_x = [0, 0.1, 0.2, 0.3]
    deriv_list = [0.1, 0.15, 0.08, 0.03]
    return local_min, list_x, deriv_list

# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=0)

# Generating x values for plotting
x_2 = np.linspace(-2, 2, 100)

# Plot function and derivative and scatter plot side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)
plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)
plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Example 3 - Divergence and Overflow
#
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %%
## TASK-4 : Code the same things as they were done for the first two examples

# %% [markdown]
# # The Learning Rate

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming these functions are defined somewhere in your code
def g(x):
    return x**2  # Replace with your actual cost function

def dg(x):
    return 2*x   # Replace with the derivative of your cost function

def gradient_descent(derivative_func, initial_guess, multiplier=0.01, precision=0.001, max_iter=1000):
    # Implement gradient descent logic here
    # Calculate local_min, list_x, and deriv_list
    # Example placeholder values for demonstration purposes:
    local_min = 0
    list_x = [0, 0.1, 0.2, 0.3]
    deriv_list = [0.1, 0.15, 0.08, 0.03]
    return local_min, list_x, deriv_list

# Calling gradient descent function with specified arguments
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.02, max_iter=500)

# Generating x values for plotting
x_2 = np.linspace(-2, 2, 100)

# Plot function and derivative and scatter plot side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)
plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)
plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)
plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)
plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# Displaying the number of steps taken
print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  4

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assuming these functions are defined somewhere in your code
def dg(x):
    return x**2  # Replace with your actual cost function

def dh(x):
    return np.sin(x)  # Replace with another cost function

def gradient_descent(derivative_func, initial_guess, multiplier=0.01, precision=0.001, max_iter=1000):
    # Implement gradient descent logic here
    # Calculate local_min, list_x, and deriv_list
    # Example placeholder values for demonstration purposes:
    local_min = 0
    list_x = [0, 0.1, 0.2, 0.3]
    deriv_list = [0.1, 0.15, 0.08, 0.03]
    return local_min, list_x, deriv_list

# Run gradient descent for different learning rates
n = 100
low_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.0005, precision=0.0001, max_iter=n)
mid_gamma = gradient_descent(derivative_func=dh, initial_guess=2, multiplier=0.001, precision=0.0001, max_iter=n)
high_gamma = gradient_descent(derivative_func=dh, initial_guess=2, multiplier=0.002, precision=0.0001, max_iter=n)
insane_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.25, precision=0.0001, max_iter=n)

# Plot results
plt.figure(figsize=[15, 5])

# Chart: Cost function
plt.subplot(1, 2, 1)
plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

x_vals = np.linspace(-2, 3, 100)
plt.plot(x_vals, dg(x_vals), color='blue', linewidth=3, alpha=0.8)

plt.scatter(low_gamma[1], dg(np.array(low_gamma[1])), color='red', s=100, alpha=0.6, label='Low Gamma')
plt.scatter(mid_gamma[1], dh(np.array(mid_gamma[1])), color='green', s=100, alpha=0.6, label='Mid Gamma')
plt.scatter(high_gamma[1], dh(np.array(high_gamma[1])), color='orange', s=100, alpha=0.6, label='High Gamma')
plt.scatter(insane_gamma[1], dg(np.array(insane_gamma[1])), color='purple', s=100, alpha=0.6, label='Insane Gamma')

plt.legend()

# Chart: Derivative
plt.subplot(1, 2, 2)
plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()

plt.plot(x_vals, dg(x_vals), color='blue', linewidth=3, alpha=0.8)

plt.scatter(low_gamma[1], low_gamma[2], color='red', s=100, alpha=0.6, label='Low Gamma')
plt.scatter(mid_gamma[1], mid_gamma[2], color='green', s=100, alpha=0.6, label='Mid Gamma')
plt.scatter(high_gamma[1], high_gamma[2], color='orange', s=100, alpha=0.6, label='High Gamma')
plt.scatter(insane_gamma[1], insane_gamma[2], color='purple', s=100, alpha=0.6, label='Insane Gamma')

plt.legend()

plt.show()

# Displaying the number of steps taken
print('Number of steps for Low Gamma is:', len(low_gamma[1]))
print('Number of steps for Mid Gamma is:', len(mid_gamma[1]))
print('Number of steps for High Gamma is:', len(high_gamma[1]))
print('Number of steps for Insane Gamma is:', len(insane_gamma[1]))
# Out:
# Number of steps for Low Gamma is: 4
# Number of steps for Mid Gamma is: 4
# Number of steps for High Gamma is: 4
# Number of steps for Insane Gamma is: 4

# %%
## TASK-7 : Plot reduction in cost for each iteration

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
## TASK-8 : Code the same things as they were done for the first two examples

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Define your function f(x, y) here or import it from your code
def f(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

# Generate meshgrid for x, y, and calculate corresponding f(x, y)
x_4 = np.linspace(-5, 5, 100)
y_4 = np.linspace(-5, 5, 100)
x_4, y_4 = np.meshgrid(x_4, y_4)
z_4 = f(x_4, y_4)

# Create the 3D plot
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

# Plot the surface
surf = ax.plot_surface(x_4, y_4, z_4, cmap='coolwarm', alpha=0.4)

plt.show()

# %% [markdown]
# ##########################
# ##########################
#
# ## TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
# ##########################
# ##########################
#
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = ## [REQUIRED]
#
# ## $$\frac{\partial f}{\partial y} = ## [REQUIRED]

# %%
from sympy import symbols, diff

# Define symbols x and y as variables
a, b = symbols('x y')

# Define your cost function f(x, y)
def f(x, y):
    return x**2 + y**3  # Replace with your actual cost function

# Print the defined cost function
print('Our cost function f(x, y) is: ', f(a, b))

# Calculate the partial derivative of f(x, y) with respect to x
print('Partial derivative wrt x is: ', diff(f(a, b), a))

# Evaluate the value of f(x, y) at x=1.8, y=1.0
print('Value of f(x,y) at x=1.8 y=1.0 is: ', f(a, b).evalf(subs={a: 1.8, b: 1.0}))

# Evaluate the value of the partial derivative wrt x at x=1.8, y=1.0
print('Value of partial derivative wrt x: ', diff(f(a, b), a).evalf(subs={a: 1.8, b: 1.0}))
# Out:
# Our cost function f(x, y) is:  x**2 + y**3
# Partial derivative wrt x is:  2*x
# Value of f(x,y) at x=1.8 y=1.0 is:  4.24000000000000
# Value of partial derivative wrt x:  3.60000000000000

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0]) # initial guess

for n in range(max_iter):
    gradient_x = diff(f(a, b), a).evalf(subs={a:params[0], b:params[1]})
    gradient_y = diff(f(a, b), b).evalf(subs={a:params[0], b:params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# Values in gradient array [1.57835979496953e-48 0.000129393920952435]
# Minimum occurs at x value of:  6.31343917987813e-49
# Minimum occurs at y value of:  0.00655450356419643
# The cost is:  2.81591416123232e-7

# %%
##########################
##########################

## TASK-10 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Partial derivative functions example 4
def fpx(x, y):
    return ## [REQUIRED]

def fpy(x, y):
    return ## [REQUIRED]

# %%
import numpy as np

# Define your cost function and its partial derivatives fpx and fpy
def f(x, y):
    return x**2 + y**3  # Replace with your actual cost function

def fpx(x, y):
    return 2*x  # Replace with the partial derivative of f with respect to x

def fpy(x, y):
    return 3*y**2  # Replace with the partial derivative of f with respect to y

# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0])  # initial guess

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of:', params[0])
print('Minimum occurs at y value of:', params[1])
print('The cost is:', f(params[0], params[1]))
# Out:
# Values in gradient array: [1.57835979e-48 1.29393921e-04]
# Minimum occurs at x value of: 6.313439179878134e-49
# Minimum occurs at y value of: 0.0065545035641964315
# The cost is: 2.8159141612323167e-07

# %% [markdown]
# ## Graphing 3D Gradient Descent

# %%
# Setup
multiplier = 0.1
max_iter = 200
params = np.array([1.8, 1.0]) # initial guess
values_array = params.reshape(1, 2)
print(values_array.shape)

for n in range(max_iter):
    gradient_x = fpx(params[0], params[1])
    gradient_y = fpy(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    #values_array = np.append(values_array, params.reshape(1, 2), axis=0)
    values_array = np.concatenate((values_array, params.reshape(1, 2)), axis=0)


# Results
print('Values in gradient array', gradients)
print('Minimum occurs at x value of: ', params[0])
print('Minimum occurs at y value of: ', params[1])
print('The cost is: ', f(params[0], params[1]))
# Out:
# (1, 2)
# Values in gradient array [1.86728201e-19 7.80531101e-04]
# Minimum occurs at x value of:  7.469128023985783e-20
# Minimum occurs at y value of:  0.016051951036056753
# The cost is:  4.136028083589838e-06

# %%
# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), cmap=cm.coolwarm, alpha=0.4)
ax.scatter(values_array[:, 0], values_array[:, 1],
           f(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()

# %% [markdown]
# ## For Reference, practice and play with the code below
#
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.8475351486029545
# Theta 1: 1.2227264637835913

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# In comparison, the actual y values are
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above.

def mse(y, y_hat):
    #mse_calc = 1/7 * sum((y - y_hat)**2)
    #mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc

# %%
print('Manually calculated MSE is:', mse(y_5, y_hat))
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: [0.94796558]
# MSE regression using manual calc is 0.947965575979458
# MSE regression is 0.9479655759794577

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        #print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
# Out:
# Min value of plot_cost 0.9483826526747164
# Min occurs at (i,j): (111, 91)
# Min MSE for Theta 0 at plot_t0[111][91] 0.829145728643216
# Min MSE for Theta 1 at plot_t1[111][91] 1.2311557788944723

# %% [markdown]
# ## Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size

    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)

    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.8532230461743415
# Min occurs at Theta 1: 1.2214935332607393
# MSE is: [0.94797511]

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
